# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %ls /Users/minliu/Desktop/Spring2019/COGS108/project
# Out:
# COGS108 Project Proposal.pdf  obesity rate.xlsx
# FinalProject_Guidelines.pdf   obesity_data.ipynb
# h08.xls                       obesity_rate.csv

# %%
# Find out where the current pathway is 
# %pwd
# Out:
# '/Users/minliu/Desktop/Spring2019/COGS108'

# %%
# Need to give the whole path to the file!
df = pd.read_csv('/Users/minliu/Desktop/Spring2019/COGS108/project/obesity_rate.csv')

# %%
df.head()
# Out:
#    Unnamed: 0         States   1990   1995   2000   2003   2004   2005   2006  \
# 0         1.0    Mississippi  0.150  0.194  0.239  0.284  0.281  0.295  0.306
# 1         2.0       BAlabama  0.144  0.183  0.237  0.281  0.277  0.287  0.298
# 2         3.0  West Virginia  0.144  0.177  0.226  0.277  0.276  0.286  0.294
# 3         4.0      Tennessee  0.137  0.172  0.226  0.260  0.258  0.274  0.282
# 4         5.0      Louisiana  0.137  0.170  0.221  0.256  0.256  0.267  0.278
#
#     2007   2008   2009   2010   2011   2012   2013   2014   2015   2016   2017
# 0  0.317  0.381  0.338  0.344  0.349  0.347  0.351  0.359  0.362  0.377  0.381
# 1  0.306  0.373  0.316  0.323  0.334  0.346  0.351  0.357  0.356  0.373  0.373
# 2  0.301  0.365  0.316  0.322  0.324  0.345  0.346  0.355  0.356  0.357  0.365
# 3  0.295  0.364  0.313  0.319  0.320  0.338  0.337  0.349  0.356  0.357  0.364
# 4  0.292  0.363  0.312  0.316  0.313  0.330  0.332  0.335  0.346  0.355  0.363

# %%
del df['Unnamed: 0']

# %%
df.head()
# Out:
#           States   1990   1995   2000   2003   2004   2005   2006   2007  \
# 0    Mississippi  0.150  0.194  0.239  0.284  0.281  0.295  0.306  0.317
# 1       BAlabama  0.144  0.183  0.237  0.281  0.277  0.287  0.298  0.306
# 2  West Virginia  0.144  0.177  0.226  0.277  0.276  0.286  0.294  0.301
# 3      Tennessee  0.137  0.172  0.226  0.260  0.258  0.274  0.282  0.295
# 4      Louisiana  0.137  0.170  0.221  0.256  0.256  0.267  0.278  0.292
#
#     2008   2009   2010   2011   2012   2013   2014   2015   2016   2017
# 0  0.381  0.338  0.344  0.349  0.347  0.351  0.359  0.362  0.377  0.381
# 1  0.373  0.316  0.323  0.334  0.346  0.351  0.357  0.356  0.373  0.373
# 2  0.365  0.316  0.322  0.324  0.345  0.346  0.355  0.356  0.357  0.365
# 3  0.364  0.313  0.319  0.320  0.338  0.337  0.349  0.356  0.357  0.364
# 4  0.363  0.312  0.316  0.313  0.330  0.332  0.335  0.346  0.355  0.363

# %%
df = df.T

# %%
df.index.names = ['Year']
#print(df)
#df.rename(columns={'States': 'Years'}, inplace=True)

# %%
df.dropna(axis = 1, inplace = True)

# %%
df.columns = list(df.loc['States',:])
df.drop('States', axis = 0, inplace = True) 
df.head()
# Out:
#      Mississippi BAlabama West Virginia Tennessee Louisiana Kentucky Oklahoma  \
# Year
# 1990        0.15    0.144         0.144     0.137     0.137    0.133    0.132
# 1995       0.194    0.183         0.177     0.172      0.17     0.17    0.169
# 2000       0.239    0.237         0.226     0.226     0.221    0.219    0.217
# 2003       0.284    0.281         0.277      0.26     0.256    0.252    0.252
# 2004       0.281    0.277         0.276     0.258     0.256    0.253    0.253
#
#      South Carolina Arkansas Michigan   ...   Oregon Wyoming Minnesota Nevada  \
# Year                                    ...
# 1990          0.127    0.123    0.123   ...    0.101   0.099     0.099  0.093
# 1995          0.166    0.166    0.164   ...    0.135   0.134     0.131   0.13
# 2000          0.217    0.214    0.211   ...    0.173   0.171     0.171   0.17
# 2003          0.252     0.25    0.249   ...    0.208   0.203     0.202  0.202
# ...

# %%
stats=pd.DataFrame()
stats["mean"]=df.mean()
stats["Std.Dev"]=df.std()
stats["Var"]=df.var()
stats.T
# Out:
#          Mississippi  BAlabama  West Virginia  Tennessee  Louisiana  Kentucky  \
# mean        0.314167  0.306389       0.301778   0.295611   0.291222  0.288500
# Std.Dev     0.064979  0.064802       0.063957   0.065616   0.064457  0.064154
# Var         0.004222  0.004199       0.004091   0.004305   0.004155  0.004116
#
#          Oklahoma  South Carolina  Arkansas  Michigan    ...       Oregon  \
# mean     0.284778        0.281778  0.279556  0.276889    ...     0.232000
# Std.Dev  0.061945        0.061452  0.061177  0.060363    ...     0.051389
# Var      0.003837        0.003776  0.003743  0.003644    ...     0.002641
#
#           Wyoming  Minnesota    Nevada  California  New York  Rhode Island  \
# mean     0.230722   0.229722  0.227611    0.226222  0.224222      0.221444
# Std.Dev  0.051778   0.051721  0.051775    0.051313  0.050780      0.049812
# Var      0.002681   0.002675  0.002681    0.002633  0.002579      0.002481
#
#          New Jersey   Montana   Vermont
# ...

# %%
sns.barplot( y = stats.index, x = stats['mean'], data = stats)
sns.set(rc={'figure.figsize':(60,50)})
sns.set(font_scale=4)
